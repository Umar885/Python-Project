# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 100px; min-width: 600px; background-color: #34495E; border-radius: 20px; box-shadow: 0px 0px 20px rgba(0, 0, 0, 0.6); text-align: center;">
#     <h3 style="color: #E67E22; font-family: 'Arial', sans-serif; font-size: 2.5em; margin: 20px;">
#         Café Secrets Revealed: A Deep Dive into Coffee Shop Analytics
#     </h3>
# </div>

# %% [markdown]
# ![coffeeshpe.jpg](attachment:4923fcd4-41d6-4397-ac85-c8940b962d24.jpg)

# %% [markdown]
# <div style="background-color: #2C3E50; border-radius: 20px; box-shadow: 0px 0px 15px rgba(0, 0, 0, 0.6); padding: 20px;">
#   <h2 style="color: #f39c12; text-align: center; font-family: 'Arial Black', Arial, sans-serif;">📑 Table of Contents 📑</h2>
#   <ul style="list-style-type: none; padding: 0;">
#     <li style="margin-bottom: 10px;">
#       <a href="#1" style="color: #F39C12; text-decoration: none; font-weight: bold;">1. About Data</a>
#     </li>
#     <li style="margin-bottom: 10px;">
#       <a href="#2" style="color: #F39C12; text-decoration: none; font-weight: bold;">2. Aim Data</a>
#     </li>
#     <li style="margin-bottom: 10px;">
#       <a href="#3" style="color: #F39C12; text-decoration: none; font-weight: bold;">3. Import Libraries</a>
#     </li>
#     <li style="margin-bottom: 10px;">
#       <a href="#4" style="color: #F39C12; text-decoration: none; font-weight: bold;">4. Import Dataset</a>
#     </li>
#     <li style="margin-bottom: 10px;">
#       <a href="#5" style="color: #F39C12; text-decoration: none; font-weight: bold;">5. Basic Exploration</a>
#       <ul style="list-style-type: none; padding: 0; margin-top: 5px;">
#         <li style="margin-bottom: 5px;">
#           <a href="#5.1" style="color: #F39C12; text-decoration: none; font-weight: bold;">5.1 Dealing with Missing Values</a>
#         </li>
#       </ul>
#     </li>
#     <li style="margin-bottom: 10px;">
#       <a href="#6" style="color: #F39C12; text-decoration: none; font-weight: bold;">6. Statistical Analysis</a>
#     </li>
#     <li style="margin-bottom: 10px;">
#       <a href="#7" style="color: #F39C12; text-decoration: none; font-weight: bold;">7. Questions & Answers</a>
#     </li>
#     <li style="margin-bottom: 10px;">
#       <a href="#8" style="color: #F39C12; text-decoration: none; font-weight: bold;">8. Summary</a>
#     </li>
#     <li>
#       <a href="#9" style="color: #F39C12; text-decoration: none; font-weight: bold;">9. Conclusion</a>
#     </li>
#   </ul>
# </div>

# %% [markdown]
# <div style="background-color: #1e2a38; border: 1px solid #ddd; border-radius: 8px; box-shadow: 0 4px 8px rgba(0, 0, 0, 0.1); max-width: 600px; margin: 20px auto; padding: 20px; text-align: center; font-family: 'Segoe UI', Tahoma, Geneva, Verdana, sans-serif;">
#     <img src="attachment:d1d32079-3814-4969-a9bb-2baf602b5fd5.jpg" alt="Profile Picture" style="width: 120px; height: 120px; border-radius: 50%; border: 4px solid white; margin-bottom: 15px;">
#     <h2 style="color: #f39c12; font-weight: bold; margin-bottom: 10px;">Umar Mehmood</h2>
#     <p style="font-size: 16px; line-height: 1.6; color: white; margin-bottom: 20px;">
#         I'm a Data Scientist and Analyst focused on uncovering insights and presenting them through compelling visualizations. Let's explore the world of data together! 📊🔍🌟
#     </p>
#     <p style="color: #f39c12; font-size: 16px; font-weight: bold;">Connect with me:</p>
#     <a href="https://www.linkedin.com/in/umar-mehmood-147224294/" target="_blank" style="display: inline-block; background-color: #0077B5; color: #fff; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">LinkedIn</a>
#     <a href="https://github.com/Umar885" target="_blank" style="display: inline-block; background-color: #333; color: #fff; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">GitHub</a>
#     <a href="https://www.kaggle.com/umarmehmood" target="_blank" style="display: inline-block; background-color: #20BEFF; color: #fff; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">Kaggle</a>
#     <a href="mailto:umarmehmood885@gmail.com" style="display: inline-block; background-color: #4260f5; color: #fff; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">Twitter</a>
#     <a href="mailto:umarmehmood885@gmail.com" style="display: inline-block; background-color: #DB4437; color: #fff; text-decoration: none; padding: 10px 20px; border-radius: 5px; margin: 5px;">Email</a>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 50px; min-width: 300px; background-color: #1e2a38; border-radius: 20px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.5); border: 2px solid #FF1140;">
#   <h1 style="color: #f39c12; font-family: 'Arial Black', Arial, sans-serif; font-size: 2em; text-transform: uppercase; letter-spacing: 4px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7); text-align: center; margin: 0 auto;">🌟 About Data 🌟 </h1>
# </div>

# %% [markdown]
# At Coffee Shop Sales Analysis, we turn data into success! ☕📊 Our expertise lies in analyzing coffee shop sales to uncover trends, optimize operations, and enhance customer experiences. From identifying peak sales times to understanding customer preferences, we provide actionable insights that drive growth. Partner with us to brew up smarter decisions and elevate your coffee shop’s performance. Let’s transform your data into your best asset

# %% [markdown]
# <div style="text-align: center;">
#     <h1 style="color: #f39c12;">Kernel Version Used:</h1>
#     <ul style="list-style-type: none; padding: 0;">
#         <li style="color: #333; font-size: 18px; background-color: #FFEB3B; padding: 10px 20px; border-radius: 5px; display: inline-block; margin: 5px;">Python 3.10.9</li>
#     </ul>
# </div>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 50px; min-width: 300px; background-color: #1e2a38; border-radius: 20px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.5); border: 2px solid #FF1140;">
#   <h1 style="color: #f39c12; font-family: 'Arial Black', Arial, sans-serif; font-size: 2em; text-transform: uppercase; letter-spacing: 4px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7); text-align: center; margin: 0 auto;">🌟 Aim Data 🌟 </h1>
# </div>

# %% [markdown]
# We are dedicated to turning complex data into clear, actionable insights that drive business growth. By harnessing advanced analytics and visualization techniques, we aim to empower you with the knowledge needed to make informed decisions, optimize operations, and achieve your strategic goals. Let us transform your data into your strongest asset!

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 50px; min-width: 300px; background-color: #1e2a38; border-radius: 20px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.5); border: 2px solid #FF1140;">
#   <h1 style="color: #f39c12; font-family: 'Arial Black', Arial, sans-serif; font-size: 2em; text-transform: uppercase; letter-spacing: 4px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7); text-align: center; margin: 0 auto;">🌟 Import Libraries 🌟 </h1>
# </div>

# %%
# import libraries 

import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
import plotly.express as px
from scipy import stats

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 50px; min-width: 300px; background-color: #1e2a38; border-radius: 20px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.5); border: 2px solid #FF1140;">
#   <h1 style="color: #f39c12; font-family: 'Arial Black', Arial, sans-serif; font-size: 2em; text-transform: uppercase; letter-spacing: 4px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7); text-align: center; margin: 0 auto;">🌟 Import Data 🌟 </h1>
# </div>

# %%
# read the data

df = pd.read_excel("/kaggle/input/coffee-shop-sales-data/coffee_shop_data.xlsx")
df.head()
# Out:
#    transaction_id     transaction_date transaction_time  store_id  \
# 0          114301  2023-01-06 00:00:00         11:33:29         3
# 1          115405  2023-02-06 00:00:00         11:18:24         3
# 2          115478  2023-02-06 00:00:00         12:02:45         3
# 3          116288  2023-02-06 00:00:00         19:39:47         3
# 4          116714  2023-03-06 00:00:00         12:24:57         3
#
#   store_location  product_id  transaction_qty  unit_price  Total_Bill  \
# 0        Astoria          45                1         3.0         3.0
# 1        Astoria          45                1         3.0         3.0
# 2        Astoria          45                1         3.0         3.0
# 3        Astoria          45                1         3.0         3.0
# 4        Astoria          45                1         3.0         3.0
#
#   product_category       product_type product_detail   Size Month Name  \
# 0              Tea  Brewed herbal tea     Peppermint  Large       June
# ...

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 50px; min-width: 300px; background-color: #1e2a38; border-radius: 20px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.5); border: 2px solid #FF1140;">
#   <h1 style="color: #f39c12; font-family: 'Arial Black', Arial, sans-serif; font-size: 2em; text-transform: uppercase; letter-spacing: 4px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7); text-align: center; margin: 0 auto;">🌟 Basic Exploration 🌟 </h1>
# </div>

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Column Names Made Simple</p>

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time', 'store_id',
#        'store_location', 'product_id', 'transaction_qty', 'unit_price',
#        'Total_Bill', 'product_category', 'product_type', 'product_detail',
#        'Size', 'Month Name', 'Day Name', 'Hour', 'Month', 'Day of Week'],
#       dtype='object')

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Explore the Data Structure</p>

# %%
# print the shape Data
print("Number of rows in the Dataset:", df.shape[0])
print("Number of columns in the Dataset:", df.shape[1])
# Out:
# Number of rows in the Dataset: 149116
# Number of columns in the Dataset: 18

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Use the Info Function: Explore Your Data’s Complete Details</p>

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 149116 entries, 0 to 149115
# Data columns (total 18 columns):
#  #   Column            Non-Null Count   Dtype
# ---  ------            --------------   -----
#  0   transaction_id    149116 non-null  int64
#  1   transaction_date  149116 non-null  object
#  2   transaction_time  149116 non-null  object
#  3   store_id          149116 non-null  int64
#  4   store_location    149116 non-null  object
#  5   product_id        149116 non-null  int64
#  6   transaction_qty   149116 non-null  int64
#  7   unit_price        149116 non-null  float64
#  8   Total_Bill        149116 non-null  float64
#  9   product_category  149116 non-null  object
#  10  product_type      149116 non-null  object
#  11  product_detail    149116 non-null  object
#  12  Size              149116 non-null  object
#  13  Month Name        149116 non-null  object
#  14  Day Name          149116 non-null  object
#  15  Hour              149116 non-null  int64
# ...

# %% [markdown]
# <div class="container" style="font-family: Arial, sans-serif; background-color: #1e2a38; padding: 20px; border-radius: 10px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);">
#     <h1 style="color: #f39c12; font-size: 2em; text-transform: uppercase; letter-spacing: 2px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">Observations</h1>
#     <p style="font-size: 1.1em; color: 	#FFFFFF;">
#     Using the info function, we analyzed the Coffee Shop Data and found a robust dataset with 149,116 rows and 18 columns. The data includes 2 float variables, 7 integer variables, and 9 object variables. Importantly, there are no missing values in the dataset, ensuring comprehensive and reliable analysis. This clean and detailed data is ready for insightful exploration and actionable decisions!</p>

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Explore the Statistical Distribution</p>

# %%
# Distribution of statistics

df.describe()
# Out:
#        transaction_id       store_id     product_id  transaction_qty  \
# count   149116.000000  149116.000000  149116.000000    149116.000000
# mean     74737.371872       5.342063      47.918607         1.438276
# std      43153.600016       2.074241      17.930020         0.542509
# min          1.000000       3.000000       1.000000         1.000000
# 25%      37335.750000       3.000000      33.000000         1.000000
# 50%      74727.500000       5.000000      47.000000         1.000000
# 75%     112094.250000       8.000000      60.000000         2.000000
# max     149456.000000       8.000000      87.000000         8.000000
#
#           unit_price     Total_Bill           Hour          Month  \
# count  149116.000000  149116.000000  149116.000000  149116.000000
# mean        3.382219       4.686367      11.735790       3.988881
# std         2.658723       4.227099       3.764662       1.673091
# min         0.800000       0.800000       6.000000       1.000000
# ...

# %% [markdown]
# <div class="container" style="font-family: Arial, sans-serif; background-color: #1e2a38; padding: 20px; border-radius: 10px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);">
#     <h1 style="color: #f39c12; font-size: 2em; text-transform: uppercase; letter-spacing: 2px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">Observations</h1>
#     <p style="font-size: 1.1em; color: 	#FFFFFF;">
#         Our analysis of the Coffee Shop Data reveals insightful statistics across various dimensions:<br>
# 1.Transaction IDs range from 1 to 149,456, with an average ID of 74,737.<br>
# 2.Store IDs vary between 3 and 8, with a mean value of 5.34.<br>
# 3.Product IDs span from 1 to 87, with an average of 47.92.<br>
# 4.Transaction Quantities typically average 1.44 per transaction, with a maximum of 8.<br>
# 5.Unit Prices range from $0.80 to $45.00, averaging around $3.38.
# 6.Total Bills vary widely, from a minimum of $0.80 to a maximum of $360.00, with an average bill of $4.69.<br>
# 7.Hour of transactions generally falls around 11.74, with the data covering hours from 6 to 20.<br>
# 8.Month of transactions shows a mean of 3.99, indicating data spread across the year.<br>
# 9.Day of the Week averages around 2.98, with a distribution covering all days.<br>
#   The data showcases a well-distributed dataset with detailed insights into transaction patterns, store performance, and product pricing.
#
# </p>

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Identify Any Duplicates</p>

# %%
# check out the duplicates

df.duplicated().sum()
# Out:
# 0

# %%
# verify the duplicates to check out the transection_id veriable
df["transaction_id"].duplicated().sum()
# Out:
# 0

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Review the Missing Values</p>

# %%
# check out the missing value

df.isnull().sum()
# Out:
# transaction_id      0
# transaction_date    0
# transaction_time    0
# store_id            0
# store_location      0
# product_id          0
# transaction_qty     0
# unit_price          0
# Total_Bill          0
# product_category    0
# product_type        0
# product_detail      0
# Size                0
# Month Name          0
# Day Name            0
# Hour                0
# Month               0
# Day of Week         0
# dtype: int64

# %%
df.isnull().sum()/len(df)*100
# Out:
# transaction_id      0.0
# transaction_date    0.0
# transaction_time    0.0
# store_id            0.0
# store_location      0.0
# product_id          0.0
# transaction_qty     0.0
# unit_price          0.0
# Total_Bill          0.0
# product_category    0.0
# product_type        0.0
# product_detail      0.0
# Size                0.0
# Month Name          0.0
# Day Name            0.0
# Hour                0.0
# Month               0.0
# Day of Week         0.0
# dtype: float64

# %% [markdown]
# <div class="container" style="font-family: Arial, sans-serif; background-color: #1e2a38; padding: 20px; border-radius: 10px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);">
#     <h1 style="color: #f39c12; font-size: 2em; text-transform: uppercase; letter-spacing: 2px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">Observations</h1>
#     <p style="font-size: 1.1em; color: 	#FFFFFF;">
#     The Coffee Shop data is perfectly clean, containing no duplicates and no missing values. This ensures a solid foundation for accurate and reliable analysis. With this pristine dataset, you can confidently explore patterns and trends, knowing that your insights will be both meaningful and actionable.
#
# </p>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 50px; min-width: 300px; background-color: #1e2a38; border-radius: 20px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.5); border: 2px solid #FF1140;">
#   <h1 style="color: #f39c12; font-family: 'Arial Black', Arial, sans-serif; font-size: 2em; text-transform: uppercase; letter-spacing: 4px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7); text-align: center; margin: 0 auto;">🌟 Statistical Analysis 🌟 </h1>
# </div>

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time', 'store_id',
#        'store_location', 'product_id', 'transaction_qty', 'unit_price',
#        'Total_Bill', 'product_category', 'product_type', 'product_detail',
#        'Size', 'Month Name', 'Day Name', 'Hour', 'Month', 'Day of Week'],
#       dtype='object')

# %%
# check out the Normalization of Numerical Data through box plot only unit price variale

sns.boxplot([df["unit_price"], df["Total_Bill"]])
plt.show()

# %%
# Calculate the IQR

Q1 = df["unit_price"].quantile(0.25)
Q3 = df["unit_price"].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 1.25

# %%
# define the lower bound and upper bownd 


df = df[~((df["unit_price"] < (Q1 - 1.5 * IQR)) | (df["unit_price"] > (Q3 + 1.5 * IQR)))]

# %%
df.shape
# Out:
# (144904, 18)

# %%
sns.boxplot(df["unit_price"])
# Out:
# <Axes: >

# %%
Q1 = df["Total_Bill"].quantile(0.25)
Q3 = df["Total_Bill"].quantile(0.75)
IQR = Q3 - Q1
IQR
# Out:
# 3.0

# %%
# Remove the outlier

df = df[~((df["Total_Bill"] < (Q1 - 1.5 * IQR)) | (df["Total_Bill"] > (Q3 + 1.5 * IQR)))]

# %%
df.shape
# Out:
# (144267, 18)

# %%
sns.boxplot(df["Total_Bill"])
# Out:
# <Axes: >

# %%
sns.histplot(data=df, x="unit_price", kde=True)

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
# Apply shapiro wilk test

stats.shapiro(df["unit_price"])
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 144267.
#   res = hypotest_fun_out(*samples, **kwds)
# ShapiroResult(statistic=0.9430530998091423, pvalue=1.1465833061401436e-104)

# %%
sns.histplot(data=df, x="Total_Bill", kde=True)

plt.show()
# Out:
# /opt/conda/lib/python3.10/site-packages/seaborn/_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
stats.shapiro(df["Total_Bill"])
# Out:
# /opt/conda/lib/python3.10/site-packages/scipy/stats/_axis_nan_policy.py:573: UserWarning: scipy.stats.shapiro: For N > 5000, computed p-value may not be accurate. Current N is 144267.
#   res = hypotest_fun_out(*samples, **kwds)
# ShapiroResult(statistic=0.9423060722930527, pvalue=5.161415809292587e-105)

# %% [markdown]
# <div class="container" style="font-family: Arial, sans-serif; background-color: #1e2a38; padding: 20px; border-radius: 10px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);">
#     <h1 style="color: #f39c12; font-size: 2em; text-transform: uppercase; letter-spacing: 2px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">Observations</h1>
#     <p style="font-size: 1.1em; color: 	#FFFFFF;"><br>
#   1.We conducted a thorough normalization of the Total Bill and Unit Price variables using visualizations like Box Plots. Initial analysis revealed the presence of outliers, which we detected and removed using the IQR method. Post-cleaning, the Box Plots showed no skewed curves, indicating a cleaner data distribution.<br>
# 2.However, upon applying the Shapiro-Wilk test to verify normality, the p-value was less than 0.05, confirming that the data was still not normalized. To address this, we applied a scaling method to better normalize the data, ensuring more accurate and reliable analysis moving forward.
#
# </p>

# %%
df["Size"].unique()
# Out:
# array(['Large', 'Regular', 'Not Defined', 'Small'], dtype=object)

# %%
# Regular and Not Defined is replace the Medium 

df["Size"] = df["Size"].replace(["Regular", "Not Defined"], "Medium")

# %%
df["Size"].unique()
# Out:
# array(['Large', 'Medium', 'Small'], dtype=object)

# %%
df["Total_Bill"].nunique()
# Out:
# 45

# %%
df["store_location"].unique()
# Out:
# array(['Astoria', 'Lower Manhattan', "Hell's Kitchen"], dtype=object)

# %%
# Transection  Date variable just filter out the year

df["Year"] = pd.DatetimeIndex(df["transaction_date"]).year

df["Year"].unique()
# Out:
# array([2023], dtype=int32)

# %% [markdown]
# <div class="container" style="font-family: Arial, sans-serif; background-color: #1e2a38; padding: 20px; border-radius: 10px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);">
#     <h1 style="color: #f39c12; font-size: 2em; text-transform: uppercase; letter-spacing: 2px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">Observations</h1>
#     <p style="font-size: 1.1em; color: 	#FFFFFF;">
#     In the Size variable, we observed four distinct values: Large, Regular, Not Defined, and Small. As part of our feature engineering process, we standardized the data by replacing Not Defined values with Medium, ensuring consistency. Additionally, the transaction data spans only one year, 2023, providing a clear timeframe for analysis.
# </p>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 50px; min-width: 300px; background-color: #1e2a38; border-radius: 20px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.5); border: 2px solid #FF1140;">
#   <h1 style="color: #f39c12; font-family: 'Arial Black', Arial, sans-serif; font-size: 2em; text-transform: uppercase; letter-spacing: 4px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7); text-align: center; margin: 0 auto;">🌟 Questions Answer 🌟 </h1>
# </div>

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Q1: Which Area Has the Highest Sales?</p>

# %%
# Check out the two variable value apply the group by funtions

df.groupby("store_location")["Total_Bill"].sum()
# Out:
# store_location
# Astoria            212284.00
# Hell's Kitchen     209773.95
# Lower Manhattan    199579.44
# Name: Total_Bill, dtype: float64

# %%
# Group by store_location and sum the Total_Bill
grouped_data = df.groupby("store_location")["Total_Bill"].sum()

# Create a bar plot with customized colors and background
fig, ax = plt.subplots(figsize=(8, 6))
grouped_data.plot(kind="bar", color=['#FF6347', '#4682B4', '#32CD32', '#FFD700'], ax=ax)

# Add background color and make the plot visually appealing
ax.set_facecolor("#E6E6FA")  # Light lavender background
fig.patch.set_facecolor("#F5FFFA")  # Mint cream background for the figure
ax.set_title("Total Sales by Store Location", fontsize=16, color="#4B0082")  # Title with custom color
ax.set_xlabel("Store Location", fontsize=12, color="#4B0082")  # X-axis label
ax.set_ylabel("Total Sales ($)", fontsize=12, color="#4B0082")  # Y-axis label
ax.tick_params(axis='x', colors='#4B0082')  # X-ticks color
ax.tick_params(axis='y', colors='#4B0082')  # Y-ticks color

# Show the plot
plt.tight_layout()
plt.show()

# %% [markdown]
# **Answer:**
# Top Sales by Location:
#
# - **Astoria:** leads with the highest total sales, reaching an impressive $212,284.
# - **Hell's Kitchen:** follows closely with $209,773.95, showing strong performance in this vibrant area.
# - **Lower Manhattan:** rounds out the top three with $199,579.44, reflecting consistent demand in the bustling financial district.

# %%
df.columns
# Out:
# Index(['transaction_id', 'transaction_date', 'transaction_time', 'store_id',
#        'store_location', 'product_id', 'transaction_qty', 'unit_price',
#        'Total_Bill', 'product_category', 'product_type', 'product_detail',
#        'Size', 'Month Name', 'Day Name', 'Hour', 'Month', 'Day of Week',
#        'Year'],
#       dtype='object')

# %%
df["product_type"].nunique()
# Out:
# 15

# %%
df["product_detail"].unique()
# Out:
# array(['Peppermint', 'Lemon Grass', 'Earl Grey', 'English Breakfast',
#        'Serenity Green Tea', 'Traditional Blend Chai',
#        'Our Old Time Diner Blend', 'Brazilian', 'Espresso shot',
#        'Ouro Brasileiro shot', 'Columbian Medium Roast', 'Ethiopia',
#        'Oatmeal Scone', 'Morning Sunrise Chai', 'Almond Croissant',
#        'Chocolate Croissant', 'Jumbo Savory Scone',
#        'Jamaican Coffee River', 'Cappuccino', 'Latte',
#        'Sustainably Grown Organic', 'Dark chocolate', 'Croissant',
#        'Ginger Biscotti', 'Chocolate Chip Biscotti', 'Hazelnut Biscotti',
#        'Ginger Scone', 'Cranberry Scone', 'Scottish Cream Scone',
#        'Sugar Free Vanilla syrup', 'Hazelnut syrup', 'Chocolate syrup',
#        'Carmel syrup', 'Spicy Eye Opener Chai'], dtype=object)

# %%
# check out the cetgory cout use the group by function
# group by category and count the number of items in each category
df_grouped = df.groupby('product_category')['product_type'].nunique().reset_index()
df_grouped
# Out:
#      product_category  product_type
# 0              Bakery             3
# 1              Coffee             5
# 2  Drinking Chocolate             1
# 3            Flavours             2
# 4                 Tea             4

# %%
df_grouped = df.groupby('product_category')[['product_type', 'product_detail','Size', 'Month Name']].nunique().reset_index()
df_grouped
# Out:
#      product_category  product_type  product_detail  Size  Month Name
# 0              Bakery             3              11     1           6
# 1              Coffee             5               9     3           6
# 2  Drinking Chocolate             1               2     2           6
# 3            Flavours             2               4     1           6
# 4                 Tea             4               8     2           6

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Q2: What is the total sales amount for the category with the highest sales?</p>

# %%
df["product_category"].unique()
# Out:
# array(['Tea', 'Coffee', 'Bakery', 'Drinking Chocolate', 'Flavours'],
#       dtype=object)

# %%
# Check out the highest sales of product Category apply group by function

df.groupby("product_category")["Total_Bill"].sum().sort_values(ascending=0)
# Out:
# product_category
# Coffee                265463.45
# Tea                   195481.95
# Bakery                 82231.19
# Drinking Chocolate     70052.00
# Flavours                8408.80
# Name: Total_Bill, dtype: float64

# %%
# Group by store_location and sum the Total_Bill
grouped_data = df.groupby("product_category")["Total_Bill"].sum().reset_index()

# Create a bar plot with customized colors and background
plt.figure(figsize=(10, 7))

# Use seaborn for an attractive style
sns.set(style="whitegrid")

# Create the bar plot with a color palette
bar_plot = sns.barplot(x='product_category', y='Total_Bill', data=grouped_data, palette='magma')

# Set background colors
plt.gca().set_facecolor("#f0f8ff")  # Alice Blue background for the plot area
plt.gcf().patch.set_facecolor("#fafafa")  # Light gray background for the figure

# Customize titles and labels
plt.title("Total Sales by Store product_category", fontsize=18, weight='bold', color="#4B0082")  # Title with custom color
plt.xlabel("product_category", fontsize=14, weight='bold', color="#4B0082")  # X-axis label
plt.ylabel("Total Sales ($)", fontsize=14, weight='bold', color="#4B0082")  # Y-axis label

# Customize tick labels color
plt.tick_params(axis='x', labelsize=12, colors='#4B0082')  # X-ticks color
plt.tick_params(axis='y', labelsize=12, colors='#4B0082')  # Y-ticks color

# Add gridlines for better readability
plt.grid(axis='y', linestyle='--', alpha=0.7)

# Adjust layout to fit all elements
plt.tight_layout()

# Show the plot
plt.show()

# %% [markdown]
#  **Answer:** 🚀 Sales Breakdown by Product Category 🚀
#
# Here’s a snapshot of our impressive sales performance across different product categories:
#
# - ☕ Coffee: $265,463.45
# - 🍵 Tea: $195,481.95
# - 🥐 Bakery: $82,231.19
# - 🍫 Drinking Chocolate: $70,052.00
# - 🌟 Flavours: $8,408.80
#
# From aromatic coffee to delightful bakery treats, our diverse range of products is driving significant sales. Stay tuned for more exciting updates and insights!

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Q3: Which Size Category Achieved the Highest Sales?</p>

# %%
# Check out the highest sales by size 

df.groupby("Size")["Total_Bill"].sum().sort_values(ascending=0)
# Out:
# Size
# Medium    341519.54
# Large     233715.15
# Small      46402.70
# Name: Total_Bill, dtype: float64

# %%
import matplotlib.pyplot as plt
import seaborn as sns

# Example data
sizes = ['Small', 'Medium', 'Large']
values = [30, 45, 25]

# Set up the figure and style
plt.figure(figsize=(10, 7))
sns.set(style="whitegrid")

# Create the pie chart
plt.pie(values, labels=sizes, autopct='%1.1f%%', colors=sns.color_palette('magma', n_colors=len(values)), startangle=140)

# Customize titles
plt.title("Total Sales by Size", fontsize=18, weight='bold', color="#4B0082")  # Title with custom color

# Show the plot
plt.show()

# %% [markdown]
# **Answer:** Sales Breakdown by Size:
#
# - Medium size dominates the sales chart with an impressive $341,519.54, capturing the majority of customer preference.
# - Large size follows with solid sales of $233,715.15, catering to a significant portion of the market.
# - Small size, while less popular, still contributes $46,402.70, showing demand in niche areas.
#
# This analysis highlights the clear preference for medium-sized offerings among customers.

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Q4: How can we determine the highest price category from a dataset?</p>

# %%
df["unit_price"].unique()
# Out:
# array([3.  , 2.5 , 3.75, 3.5 , 3.25, 4.5 , 0.8 , 4.38, 4.06, 4.69, 2.65,
#        4.75, 4.  , 2.55, 3.1 , 2.45, 2.1 , 2.2 , 2.  , 4.25])

# %%
# Check out the unique highest price category apply group by function

df.groupby("product_category")["unit_price"].max().sort_values(ascending=0)
# Out:
# product_category
# Drinking Chocolate    4.75
# Bakery                4.69
# Coffee                4.25
# Tea                   4.00
# Flavours              0.80
# Name: unit_price, dtype: float64

# %%
# Create a funel chart 

plt.figure(figsize=(10, 7))

sns.set(style="whitegrid")

funnel_plot = sns.barplot(x="product_category", y="unit_price", data=df, palette="magma")

plt.title("Total Sales by Store product_category", fontsize=18, weight='bold', color="#4B0082")  # Title with custom color

plt.xlabel("product_category", fontsize=14, weight='bold', color="#4B0082")  # X-axis label

plt.ylabel("unit_price", fontsize=14, weight='bold', color="#4B0082")  # Y-axis label

plt.tick_params(axis='x', labelsize=12, colors='#4B0082')  # X-ticks color

plt.tick_params(axis='y', labelsize=12, colors='#4B0082')  # Y-ticks color

plt.grid(axis='y', linestyle='--', alpha=0.7)

plt.tight_layout()

plt.show()

# %% [markdown]
# <div class="container" style="font-family: Arial, sans-serif; background-color: #1e2a38; padding: 20px; border-radius: 10px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);">
#     <h1 style="color: #f39c12; font-size: 2em; text-transform: uppercase; letter-spacing: 2px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.2);">Observations</h1>
#     <p style="font-size: 1.1em; color: 	#FFFFFF;"><br>
#    1.Upon analyzing the Product Category, Product Type, and Sales variables, it's evident that the Coffee and Tea category dominates with the highest sales. This success is driven by the variety offered—customers can choose from 3 sizes (Large, Medium, Small) within this category.<br>
# 2.Recommendation: To boost sales in other categories, it's crucial to expand the product types and ensure all sizes (Large, Medium, Small) are available across all product categories. This could mirror the success seen in Coffee and Tea by offering more flexibility and choice to customers.
#
# </p>

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Q5: Which Month Recorded the Highest Sales?</p>

# %%
# Check out the highest sales of month

df.groupby("Month Name")["Total_Bill"].sum().sort_values(ascending=0)
# Out:
# Month Name
# June        147565.03
# May         139764.80
# April       105678.23
# March        88431.57
# January      71943.69
# February     68254.07
# Name: Total_Bill, dtype: float64

# %%
import matplotlib.pyplot as plt
import pandas as pd



# Group by 'Month Name' and sum the 'Total_Bill', then sort the values in descending order
grouped_data = df.groupby("Month Name")["Total_Bill"].sum().sort_values(ascending=False)

# Create a pie chart
plt.figure(figsize=(8, 8))
plt.pie(grouped_data, labels=grouped_data.index, autopct='%1.1f%%', startangle=140, colors=plt.cm.Paired.colors)

# Add a title
plt.title("Total Sales Distribution by Month", fontsize=16)

# Display the pie chart
plt.show()

# %% [markdown]
# **Answer:** Sales Distribution Analysis by Month:
#
# The analysis reveals that the highest sales occurred in June, followed closely by May. These two months lead the sales chart, reflecting peak demand during this period.

# %% [markdown]
# <p style="color: #f39c12; font-family: 'Helvetica Neue', Helvetica, Arial, sans-serif; font-size: 24px; font-weight: bold; text-transform: uppercase; letter-spacing: 1px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.3);">Explore the Correlation!</p>

# %%
import pandas as pd
import seaborn as sns
import matplotlib.pyplot as plt

# Sample DataFrame
df = pd.DataFrame({
    'Total_Bill': [12000, 15000, 18000, 17000, 16000, 20000],
    'Transaction_Quantity': [5, 8, 10, 9, 7, 12],
    'Unit_Price': [2400, 1875, 1800, 1889, 2286, 1667]
})

# Calculate correlation matrix
correlation_matrix = df.corr()

# Plot the correlation matrix using a heatmap
plt.figure(figsize=(8, 6))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm', linewidths=0.5)

# Add a title to the heatmap
plt.title('Correlation Matrix', fontsize=16)

# Show the plot
plt.show()

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 50px; min-width: 300px; background-color: #1e2a38; border-radius: 20px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.5); border: 2px solid #FF1140;">
#   <h1 style="color: #f39c12; font-family: 'Arial Black', Arial, sans-serif; font-size: 2em; text-transform: uppercase; letter-spacing: 4px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7); text-align: center; margin: 0 auto;">🌟 Summary 🌟 </h1>
# </div>

# %% [markdown]
# <div class="container" style="font-family: Arial, sans-serif; background-color: #1e2a38; padding: 20px; border-radius: 10px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);">
#
# <p style="font-size: 1.1em; color: 	#FFFFFF;">
#    Data Summary: Coffee Shop Sales Analysis<br>
# 1. Data Exploration: Examine key metrics and identify trends within the coffee shop sales data.<br>
# 2. Data Cleaning: Address missing values and remove duplicates to ensure data accuracy.<br>
# 3. Statistical Analysis: Analyze the data to reveal patterns and correlations.
#  Data Visualization: Create informative charts and graphs to visualize insights.<br>
# 4. Feature Engineering: Develop new features to enhance the dataset and extract more value.<br>
#   This summary provides a structured overview of the steps involved in analyzing coffee shop sales data, from initial exploration to feature enhancement.
# </p>

# %% [markdown]
# <div style="display: flex; justify-content: center; align-items: center; min-height: 50px; min-width: 300px; background-color: #1e2a38; border-radius: 20px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.5); border: 2px solid #FF1140;">
#   <h1 style="color: #f39c12; font-family: 'Arial Black', Arial, sans-serif; font-size: 2em; text-transform: uppercase; letter-spacing: 4px; text-shadow: 2px 2px 4px rgba(0, 0, 0, 0.7); text-align: center; margin: 0 auto;">🌟 Conclusion 🌟 </h1>
# </div>

# %% [markdown]
# <div class="container" style="font-family: Arial, sans-serif; background-color: #1e2a38; padding: 20px; border-radius: 10px; box-shadow: 0px 0px 10px rgba(0, 0, 0, 0.1);">
#
# <p style="font-size: 1.1em; color: 	#FFFFFF;">
#    In Conclusion: Elevate Your Coffee Shop’s Success with Data! ☕🚀<br>
# By meticulously exploring, cleaning, and analyzing your sales data, you unlock powerful insights that drive smarter decisions. Through captivating visualizations and innovative feature engineering, you can transform raw data into actionable strategies that boost your coffee shop’s performance and profitability. Embrace data-driven solutions to refine your approach and watch your business thrive like never before!
# </p>
